# %%
from bs4 import BeautifulSoup

# %%
import pandas as pd
import requests

# %%
url = 'https://wuzzuf.net/search/jobs/?q=data+analyst&a=hpb'

# %%
page = requests.get(url)
soup = BeautifulSoup(page.text, 'html')
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, shrink-to-fit=no" name="viewport"/>
# <meta content="Thu Dec 08 2022 18:30:44 GMT+0200" http-equiv="expires">
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="no-cache, no-store, must-revalidate" http-equiv="cache-control"/>
# <title data-react-helmet="true">Job Search | WUZZUF</title>
# ...

# %%
containers = soup.find_all("div",{"class": "css-1gatmva e1v1l3u10"})

# %%
len(containers)
# Out:
# 15

# %%
bs.prettify(containers[0])
# Out:
# '<div class="css-1gatmva e1v1l3u10">\n <style data-emotion="css pkv5jc">\n  .css-pkv5jc{position:relative;min-height:60px;}\n </style>\n <div class="css-pkv5jc">\n  <a href="https://wuzzuf.net/jobs/careers/Tidal-Egypt-31908" rel="noreferrer" target="_blank">\n   <style data-emotion="css 17095x3">\n    .css-17095x3{position:absolute;right:0;top:0;width:60px;height:60px;object-fit:contain;object-position:center center;}\n   </style>\n  </a>\n  <style data-emotion="css laomuu">\n   .css-laomuu{padding-right:60px;}\n  </style>\n  <div class="css-laomuu">\n   <style data-emotion="css m604qf">\n    .css-m604qf{font-size:16px;font-weight:600;font-style:normal;letter-spacing:-0.4px;line-height:24px;color:#0055D9;margin:0;}\n   </style>\n   <h2 class="css-m604qf">\n    <style data-emotion="css o171kl">\n     .css-o171kl{-webkit-text-decoration:none;text-decoration:none;color:inherit;}\n    </style>\n    <a class="css-o171kl" href="https://wuzzuf.net/jobs/p/P4uYmYNtDVI3-Business-Data-Analyst-T
# ...

# %%
containers[0].div.h2.text
# Out:
# 'Business Data Analyst'

# %%
jtitle = containers[0].div.h2
jtitle
# Out:
# <h2 class="css-m604qf"><style data-emotion="css o171kl">.css-o171kl{-webkit-text-decoration:none;text-decoration:none;color:inherit;}</style><a class="css-o171kl" href="https://wuzzuf.net/jobs/p/P4uYmYNtDVI3-Business-Data-Analyst-Tidal-Cairo-Egypt" rel="noreferrer" target="_blank">Business Data Analyst</a></h2>

# %%
jtitle = containers[0].find_all("h2",{"class": "css-m604qf"})
jtitle[0].text
# Out:
# 'Business Data Analyst'

# %%
cname = containers[0].find_all("a",{"class": "css-17s97q8"})
cname[0].text
# Out:
# 'Tidal -'

# %%
shift_type = containers[0].find_all("div",{"class": "css-1lh32fc"})
shift_type[0].text
# Out:
# 'Full TimeShift Based'

# %%
for container in containers:
    cname = container.find_all("a",{"class": "css-17s97q8"})
    company_name = cname[0].text.strip()
    shift_type = container.find_all("div",{"class": "css-1lh32fc"})
    sh_type = shift_type[0].text.strip()
    jtitle = container.find_all("h2",{"class": "css-m604qf"})
    job_title = jtitle[0].text.strip()
    print(company_name)
    print(sh_type)
    print(job_title)
    print()
    print(job_title + ", " + company_name + ", " + sh_type )
    print()
# Out:
# Tidal -
# Full TimeShift Based
# Business Data Analyst
#
# Business Data Analyst, Tidal -, Full TimeShift Based
#
# Aman -
# Full Time
# Data Analyst
#
# Data Analyst, Aman -, Full Time
#
# Cilantro -
# Full Time
# Senior Data Analyst
#
# Senior Data Analyst, Cilantro -, Full Time
#
# Confidential -
# Full Time
# Business Data Analyst
#
# Business Data Analyst, Confidential -, Full Time
#
# Qureos -
# Full Time
# Data Analyst - United Arab Emirates University
#
# Data Analyst - United Arab Emirates University, Qureos -, Full Time
#
# Care Services EG -
# Full Time
# Data Analyst
#
# Data Analyst, Care Services EG -, Full Time
#
# MTS Logistics -
# Freelance / Project
# SQL Data Analyst
#
# SQL Data Analyst, MTS Logistics -, Freelance / Project
#
# Qureos -
# Full Time
# Senior Data Analyst - KBR
#
# Senior Data Analyst - KBR, Qureos -, Full Time
#
# 2CooM -
# Full Time
# Data Analyst
#
# Data Analyst, 2CooM -, Full Time
#
# Q-Express Documents Transport - G25 -
# Full Time
# ...
